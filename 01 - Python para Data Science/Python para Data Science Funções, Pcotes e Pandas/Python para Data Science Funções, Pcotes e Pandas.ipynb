# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUÇÃO AO PYTHON
# ---

# %% [markdown]
# # 1.1 Introdução

# %% [markdown]
# > Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto *open source* e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
# >
# > Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado.

# %% [markdown]
# # 1.2 Instalação e ambiente de desenvolvimento

# %% [markdown]
# ### Instalação Local
#
# ### https://www.python.org/downloads/
# ### ou
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versão

# %%
# !python -V
# Out:
# Python 3.7.14

# %% [markdown]
# # 1.3 Trabalhando com dados

# %%
import pandas as pd
# pd.set_option('display.max_rows', 1000)
#esse comando acima ira mostrar a quantidade de linhas selecionadas do arquivo csv, sem cortar e sem diminuir

# pd.set_option('display.max_columns', 1000)
#esse comando acima ira mostrar a quantidade de colunas selecionadas do arquivo csv, sem cortar e sem diminuir

# %%
ds = pd.read_csv('db.csv', sep = ';')

# %%
ds
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
ds.columns = ('nome', 'motor', 'ano', 'quilometragem', 'zero-km', 'acessorios', 'valor')

# %%
ds.dtypes
# Out:
# nome              object
# motor             object
# ano                int64
# quilometragem    float64
# zero-km             bool
# acessorios        object
# valor            float64
# dtype: object

# %%
ds[['quilometragem', 'valor']].describe() #como quero selecionar duas informaçaoes eu adiciono 2 [[]] e o CMD DESCRIBE é para uma analise descritiva dos valores
# Out:
#        quilometragem          valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
ds.info() #info do pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nome           258 non-null    object
#  1   motor          258 non-null    object
#  2   ano            258 non-null    int64
#  3   quilometragem  197 non-null    float64
#  4   zero-km        258 non-null    bool
#  5   acessorios     258 non-null    object
#  6   valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABALHANDO COM TUPLAS
# ---

# %% [markdown]
# # 2.1 Criando tuplas
#
# Tuplas são sequências imutáveis que são utilizadas para armazenar coleções de itens, geralmente heterogêneos. Podem ser construídas de várias formas:
# ```
# - Utilizando um par de parênteses: ( )
# - Utilizando uma vírgula à direita: x,
# - Utilizando um par de parênteses com itens separados por vírgulas: ( x, y, z )
# - Utilizando: tuple() ou tuple(iterador)
# ```

# %%
() #tupla vazia
   #tuplas é uma caixa com varias variaveis em uma unica atribuição
# Out:
# ()

# %%
1,2,3 #vai criar uma tupla
# Out:
# (1, 2, 3)

# %%
nome = 'passat'
valor = 15300
(nome, valor) #criado uma tupla, as tuplas armazenam tipos variados de dados
# Out:
# ('passat', 15300)

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5']) #convertendo uma lista em uma tupla
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type(nomes_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Seleções em tuplas

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5']) #convertendo uma lista em uma tupla
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
nomes_carros[0] #selecionarei o primeiro indice da tupla nomes_carros
# Out:
# 'Jetta Variant'

# %%
nomes_carros[2]
# Out:
# 'Crossfox'

# %%
nomes_carros[-1]
# Out:
# 'DS5'

# %%
#fazer os slices, separaçoes de colunas
nomes_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4')) #tupla dentro de tupla
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nomes_carros[4][1] #acessar o segundo item da segunda tupla
# Out:
# 'Gol'

# %%
nomes_carros[-1][1] #outra maneira
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
for item in nomes_carros: #para a variavel item 
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
carro_1, carro_2, carro_3, carro_4 = nomes_carros #atribui uma variavel para cada variavel dentro da tupla, na ordem que esta na tupla
#carro 1, vai ser jetta
#varro 2, passat
#carro 3, gol
#carro 4, ds5

# %%
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DS5'

# %%
_, a, _, b = nomes_carros #aqui estou ignorando a primeira e a terceira variavel da tupla, tem que sair a=passat e b=ds5

# %%
a
# Out:
# 'Passat'

# %%
b
# Out:
# 'DS5'

# %%
_, c, *_ = nomes_carros #aqui *_ ignora tudo apos ele, logo c= passat

# %%
c
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
car = list(zip(carros, valores)) #CMD LIST vai transformar em lista
                          #CMD ZIP vai iterar os dados de carros e valores
                          #no final serão criadas 3 tuplas contendo (carro , valor)

# %%
for item in zip(carros, valores):
  print(item)  #mesma coisa de maneira diferente
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for uva, jaca in zip(carros, valores): #uva vai pegar o indice carros E jaca vai pegar o indice valores
  print(uva, jaca) #printou de maneira diferente da de cima
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for uva, jaca in zip(carros, valores): #vai printar somente carros(uva) com valores(jaca) acimas de 100000
  if(jaca > 100000):
    print(uva)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABALHANDO COM DICIONÁRIOS
# ---

# %% [markdown]
# # 3.1 Criando dicionários
#
# Listas são coleções sequenciais, isto é, os itens destas sequências estão ordenados e utilizam índices (números inteiros) para acessar os valores.
#
# Os dicionários são coleções um pouco diferentes. São estruturas de dados que representam um tipo de mapeamento. Mapeamentos são coleções de associações entre pares de valores onde o primeiro elemento do par é conhecido como chave (*key*) e o segundo como valor (*value*).
#
# ```
# dicionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
carros.index('Passat') #retorna a posiçao do passat na lista
# Out:
# 1

# %%
valores[carros.index('Passat')] #uma maneira de mapear, porem mais complicado.
# Out:
# 106161.94

# %%
dados = {'Jetta Variant' : 88078.64, 'Passat' : 106161.94, 'Crossfox' : 72832.16} #esta dizendo que estao em pares
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
type(dados) #vai ser um tipo de dicionario
# Out:
# dict

# %% [markdown]
# ### Criando dicionários com *zip()*

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %%
dados = dict(zip(carros, valores)) #melhor forma de transormar em dicionario

# %% [markdown]
# # 3.2 Operações com dicionários

# %%
dados = {'Jetta Variant' : 88078.64, 'Passat' : 106161.94, 'Crossfox' : 72832.16} #esta dizendo que estao em pares
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %% [markdown]
# ## *dict[ key ]*
#
# Retorna o valor correspondente à chave (*key*) no dicionário.

# %%
dados['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Retorna **True** se a chave (*key*) for encontrada no dicionário.

# %%
'Passat' in dados
# Out:
# True

# %%
'Fusca' in dados
# Out:
# False

# %%
'Fusca' not in dados
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Retorna o número de itens do dicionário.

# %%
len(dados)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Inclui um item ao dicionário.

# %%
dados['ds5'] = 124549.07 #adicionando nova chave ao dicionario
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07}

# %% [markdown]
# ## *del dict[ key ]*
#
# Remove o item de chave (*key*) do dicionário.

# %%
del dados['Passat'] #exclusao de um item
dados
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'ds5': 124549.07}

# %% [markdown]
# # 3.3 Métodos de dicionários

# %% [markdown]
# ## *dict.update()*
#
# Atualiza o dicionário.

# %%
dados.update({ 'Passat': 106161.94}) #incluir mais informaçoes
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 106161.94}

# %%
#atualizar informaçoes que ja existem E adicionar um novo
dados.update({'Passat': 110000, 'Fusca' : 250000})
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 110000,
#  'Fusca': 250000}

# %% [markdown]
# ## *dict.copy()*
#
# Cria uma cópia do dicionário.

# %%
dadosCopy = dados.copy() #para copiar o dicionario (nesse caso o dicionario dados)

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 110000,
#  'Fusca': 250000}

# %%
del dadosCopy['Fusca']

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 110000}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Se a chave for encontrada no dicionário, o item é removido e seu valor é retornado. Caso contrário, o valor especificado como *default* é retornado. Se o valor *default* não for fornecido e a chave não for encontrada no dicionário um erro será gerado.

# %%
dadosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 110000}

# %%
dadosCopy.pop('Passat') #retorna qual item foi eliminado
# Out:
# 110000

# %%
dadosCopy.pop('Passat', 'chave nao encontrada') #tratando caso nao encontre o que foi solicitado, pois ja solicitei no comando acima | tratamento de erro
# Out:
# 'chave nao encontrada'

# %% [markdown]
# ## *dict.clear()*
#
# Remove todos os itens do dicionário.

# %%
dadosCopy.clear() #limpa tudo que tem no dicionario

# %%
dadosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando em dicionários

# %%
dados
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'ds5': 124549.07,
#  'Passat': 110000,
#  'Fusca': 250000}

# %% [markdown]
# ## *dict.keys()*
#
# Retorna uma lista contendo as chaves (*keys*) do dicionário.

# %%
dados.keys()
# Out:
# dict_keys(['Jetta Variant', 'Crossfox', 'ds5', 'Passat', 'Fusca'])

# %%
for k in dados.keys():
  print(dados[k])
# Out:
# 88078.64
# 72832.16
# 124549.07
# 110000
# 250000

# %% [markdown]
# ## *dict.values()*
#
# Retorna uma lista com todos os valores (*values*) do dicionário.

# %%
dados.values()
# Out:
# dict_values([88078.64, 72832.16, 124549.07, 110000, 250000])

# %% [markdown]
# ## *dict.items()*
#
# Retorna uma lista contendo uma tupla para cada par chave-valor (*key-value*) do dicionário.

# %%
dados.items()
# Out:
# dict_items([('Jetta Variant', 88078.64), ('Crossfox', 72832.16), ('ds5', 124549.07), ('Passat', 110000), ('Fusca', 250000)])

# %%
for item in dados.items():
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Crossfox', 72832.16)
# ('ds5', 124549.07)
# ('Passat', 110000)
# ('Fusca', 250000)

# %%
#desempacotamento
for k, v in dados.items():
  print(f'Carro - {k}  | valor - {v}')
# Out:
# Carro - Jetta Variant  | valor - 88078.64
# Carro - Crossfox  | valor - 72832.16
# Carro - ds5  | valor - 124549.07
# Carro - Passat  | valor - 110000
# Carro - Fusca  | valor - 250000

# %%
for k, v in dados.items():
  if(v > 100000):
    print(k)
# Out:
# ds5
# Passat
# Fusca

# %% [markdown]
# ## exercicio para printar carros apos anos 2000

# %%
dadus = {
    'Crossfox': {'valor': 72000, 'ano': 2005}, 
    'DS5': {'valor': 125000, 'ano': 2015}, 
    'Fusca': {'valor': 150000, 'ano': 1976}, 
    'Jetta': {'valor': 88000, 'ano': 2010}, 
    'Passat': {'valor': 106000, 'ano': 1998}
}

# %%
for item in dadus.items():
    print(item)
# Out:
# ('Crossfox', {'valor': 72000, 'ano': 2005})
# ('DS5', {'valor': 125000, 'ano': 2015})
# ('Fusca', {'valor': 150000, 'ano': 1976})
# ('Jetta', {'valor': 88000, 'ano': 2010})
# ('Passat', {'valor': 106000, 'ano': 1998})

# %%
for item in dadus.items():
    if(item[1]['ano'] >= 2000):
        print(item[0])
# Out:
# Crossfox
# DS5
# Jetta

# %% [markdown]
# # <font color=green> 4. FUNÇÕES E PACOTES
# ---
#
# Funções são unidades de código reutilizáveis que realizam uma tarefa específica, podem receber alguma entrada e também podem retornar alguma resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# A linguagem Python possui várias funções integradas que estão sempre acessíveis. Algumas já utilizamos em nosso treinamento: type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
#built in function são funçoes complexas ja existentes no codigo python, devido a isso as funçoes mais comuns ja possuem codigo pronto
#somatorio de variavel
for valor in dados.values():
  valores.append(valor)
valores
# Out:
# [88078.64,
#  106161.94,
#  72832.16,
#  ['Jetta Variant', 'Passat', 'Crossfox'],
#  ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
#  [2003, 1991, 1990],
#  [44410.0, 5712.0, 37123.0],
#  [False, False, False],
#  [88078.64, 106161.94, 72832.16],
#  88078.64,
#  106161.94,
#  72832.16]

# %%
soma = 0
for valor in dados.values():
  soma += valor
soma
# Out:
# 267072.74

# %%
#melharando o codigo acima
list(dados.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
sum(dados.values())
# Out:
# 267072.74

# %%
sum(dados.values(), 100000) #aqui alem da soma que estou realizando, estou definindo um valor inicial para o calculo
# Out:
# 367072.74

# %%
#acessando a biblioteca de ajuda
help(print) #help(comando que tenho duvida)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
#outra maneira de acessar ajuda no COLAB
print?

# %% [markdown]
# # 4.2 Definindo funções sem e com parâmetros

# %% [markdown]
# ### Funções sem parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>():
#     <instruções>
# ```

# %%
#criando uma funçao
def media(): #minha funçao vai se chamar media
  valor = (1 + 2 +3 ) / 3
  print(valor)

# %%
#nao aconteceu nada anteriorment, pois eu defini o que seria a minha nova funçao
#mas se eu rodar a nova funçao ira aparecer o resultado dela
media()
# Out:
# 2.0

# %% [markdown]
# ### Funções com parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
# ```

# %%
def media(num_1, num_2, num_3): #expecificando 3 paramentros para a minha funçao
  valor = (num_1 + num_2 + num_3) / 3
  print(valor)

# %%
media(5, 2, 8) #apos definir os parametros, eles se tornam variaveis
# Out:
# 5.0

# %%
media(23, 45, 67)
# Out:
# 45.0

# %%
def medio(lista):                  #definindo a funçao medio que vai ser uma lista
  valor = sum(lista) / len(lista)  #definindo que sera uma soma de tudo que estiver na lista e sera divido pela quantidade de itens que tem na lista
  print(valor)

# %%
# aora posso incluir uma lista de valores infinitos
medio([1, 2, 3, 4, 5, 6, 7, 8, 9]) #lembre-se do colchete, pois é uma lista que estou criando
# Out:
# 5.0

# %%
resultado = medio([1, 2, 3, 4, 5, 6, 7, 8, 9]) #defini RESULTADO como uma variavel
# Out:
# 5.0

# %%
resultado #porem ao rodar esta variavel, ela vai me retornar nada pois a função criada precisará sempre de novos dados

# %%
#exercicio de fixação
#descobrindia a media rodada por cada carro da lista
dedos = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
#definindo o parametro da busca
def km_media(dataset, ano_atual): #definindo a variavel e a tupla
  for item in dataset.items(): #para item que tenha nos items do dataset(a ser definido)
    resultado = item[1]['km'] / (ano_atual - item[1]['ano']) 
    print(resultado)

# %%
#definindo de onde colherá os dados
#km_media(dataset, ano_atual)
km_media(dedos, 2019)
# Out:
# 2500.0
# 4250.0
# 3250.0
# 7000.0
# 3100.0

# %% [markdown]
# # 4.3 Definindo funções que retornam valores

# %% [markdown]
# ### Funções que retornam um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return <resultado>
# ```

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  #print(valor) #ao inves de utilizar o PRINT eu utilizo o RETURN
  return valor #CMD RETURN so pode ser utilizado com o CMD DEF

# %%
media([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 5.0

# %%
resultado = media([1, 2, 3, 4, 5, 6, 7, 8, 9])

# %%
resultado #antes eu nao conseguia deixar a variavel RESULTADO definida, mas com o CMD RETURN é possivel
# Out:
# 5.0

# %% [markdown]
# ### Funções que retornam mais de um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return (valor, len(lista)) #retornando mais de uma valor

# %%
media([1, 2, 3, 4, 5, 6, 7, 8, 9]) #o resultado ira mostrar a media e quantidade de itens na lista
# Out:
# (5.0, 9)

# %%
resultado, n = media([1, 2, 3, 4, 5, 6, 7, 8, 9]) #vai armazenar em mais de uma variavel RESULTADO = VALOR | N = LEN(LISTA)

# %%
resultado #media dos valores
# Out:
# 5.0

# %%
n #quantidade de itens da lista
# Out:
# 9

# %% [markdown]
# ## EXERCICIO DE FIXAÇAO

# %% [markdown]
# ### EXERCICIO 1

# %%
#RETORNAR OS NOMES DOS VEICULOS JUNTO COM KM MEDIA
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
def km_media(dataset, ano_atual):
  resultado = {}
  for item in dataset.items():
    media = item[1]['km'] / ano_atual - item[1]['ano']
    resultado.update ({item[0]: media}) #apos rodar para a primeira linha, irá pular para a segunda e vai até a ultima linha
  return resultado

# %%
km_media(dados, 2022)
# Out:
# {'Crossfox': -1987.6904055390703,
#  'DS5': -2006.5924826904056,
#  'Fusca': -1914.7072205736895,
#  'Jetta': -1983.3046488625123,
#  'Passat': -1968.3372898120672}

# %% [markdown]
# ### EXERCICIO 2

# %%
def km_media(dataset, ano_atual):
    resultado = {}
    for item in dataset.items():
        media = item[1]['km'] / (ano_atual - item[1]['ano'])
        item[1].update({'km_media' : media}) #adicionando uma nova coluna KM_MEDIA e seu valor calculado anteriormente
        resultado.update({item[0] : item[1]}) #adicionado os items que quero que apareçam
    return resultado

# %%
km_media(dados, 2019)
# Out:
# {'Crossfox': {'km': 35000, 'ano': 2005, 'km_media': 2500.0},
#  'DS5': {'km': 17000, 'ano': 2015, 'km_media': 4250.0},
#  'Fusca': {'km': 130000, 'ano': 1979, 'km_media': 3250.0},
#  'Jetta': {'km': 56000, 'ano': 2011, 'km_media': 7000.0},
#  'Passat': {'km': 62000, 'ano': 1999, 'km_media': 3100.0}}

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versão: 0.25.2**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy. O pacote pandas possui estruturas de dados bastante interessantes para manipulação de dados e por isso é muito utilizado por cientistas de dados.
#
#
# ## Estruturas de Dados
#
# ### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte:
#
#
# ```
#     s = pd.Series(dados, index = index)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# ### DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#
# ```
#     df = pd.DataFrame(dados, index = index, columns = columns)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# **Documentação:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# # 5.1 Estruturas de dados

# %%
import pandas as pd

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['jetta', 'passat', 'crossfox']
carros
# Out:
# ['jetta', 'passat', 'crossfox']

# %%
pd.Series(carros) #transformando em uma serie os dados
# Out:
# 0       jetta
# 1      passat
# 2    crossfox
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
#transformar uma lista em planilha
dataset = pd.DataFrame(dados)

# %%
dataset #repara que as keys ja se tornam os nomes das colunas
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
dataset[['Nome', 'Motor', 'Ano', 'Quilometragem', 'Valor', 'Zero_km',]] #dois colchetes para acessar as coluna, se eu alterar a ordem aqui, será alterado na tabela
# Out:
#             Nome            Motor   Ano  Quilometragem      Valor  Zero_km
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0   88078.64    False
# 1         Passat     Motor Diesel  1991         5712.0  106161.94    False
# 2       Crossfox  Motor Diesel V8  1990        37123.0   72832.16    False

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
#outra forma de criar um df quando a lista esta de outra forma
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de uma arquivo externo

# %%
dataset = pd.read_csv('db.csv', sep = ';') #por que do separador? por causa que no arquivo raiz, cada coluna esta separado por ; (abrir no txt par ver)

# %%
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset = pd.read_csv('db.csv', sep = ';', index_col = 0) #CMD INDEX_COL=0 eu estou selecionando o que eu quero que seja o indice ao inves do padrao
dataset #repara que ao inves de numeros no indice, agora é a coluna 0 (nome)
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %% [markdown]
# ## EXERCICIO DE FIXAÇAO

# %%
#PARA A LISTA
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
# a funçao
def km_media(dataset, ano_atual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (ano_atual - item[1]['ano'])
        item[1].update({ 'km_media': media })
        result.update({ item[0]: item[1] })

    return result

chart = km_media(dados, 2019)
chart
# Out:
# {'Crossfox': {'km': 35000, 'ano': 2005, 'km_media': 2500.0},
#  'DS5': {'km': 17000, 'ano': 2015, 'km_media': 4250.0},
#  'Fusca': {'km': 130000, 'ano': 1979, 'km_media': 3250.0},
#  'Jetta': {'km': 56000, 'ano': 2011, 'km_media': 7000.0},
#  'Passat': {'km': 62000, 'ano': 1999, 'km_media': 3100.0}}

# %%
tabela = pd.DataFrame(chart)
tabela
# Out:
#           Crossfox      DS5     Fusca    Jetta   Passat
# km         35000.0  17000.0  130000.0  56000.0  62000.0
# ano         2005.0   2015.0    1979.0   2011.0   1999.0
# km_media    2500.0   4250.0    3250.0   7000.0   3100.0

# %%
#o exercicio pediu para transpor a tabela
tabela = pd.DataFrame(chart).T
tabela #perceba que inverteu as colunas pelas linhas
# Out:
#                 km     ano  km_media
# Crossfox   35000.0  2005.0    2500.0
# DS5        17000.0  2015.0    4250.0
# Fusca     130000.0  1979.0    3250.0
# Jetta      56000.0  2011.0    7000.0
# Passat     62000.0  1999.0    3100.0

# %% [markdown]
# # 5.2 Seleções com DataFrames

# %% [markdown]
# ### Selecionando colunas

# %%
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset['Valor'] #vai vir o index + a coluna solicitada
# Out:
# Nome
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
#transformar 1 unica coluna em uma tabela
#colocar em 2 colchetes
dataset[['Valor']]
# Out:
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %% [markdown]
# ### Selecionando linhas - [ i : j ]
#
# <font color=red>**Observação:**</font> A indexação tem origem no zero e nos fatiamentos (*slices*) a linha com índice i é **incluída** e a linha com índice j **não é incluída** no resultado.

# %%
dataset[:4] #da linha 0 até a linha 3
# Out:
#                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# Passat            Motor Diesel  1991         5712.0    False
# Crossfox       Motor Diesel V8  1990        37123.0    False
# DS5            Motor 2.4 Turbo  2019            NaN     True
#
#                                                       Acessórios      Valor
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat         ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox       ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5            ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %% [markdown]
# ### Utilizando .loc para seleções
#
# <font color=red>**Observação:**</font> Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
dataset.loc['Passat'] #vai retornar uma series com as informaçoes da linha do passat
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'Crossfox']] #selecionando só os index que eu quero
# Out:
#                     Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat       Motor Diesel  1991         5712.0    False
# Crossfox  Motor Diesel V8  1990        37123.0    False
#
#                                                  Acessórios      Valor
# Nome
# Passat    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox  ['Piloto automático', 'Controle de estabilidad...   72832.16

# %%
dataset.loc[['Passat', 'Crossfox'], ['Motor', 'Valor']] #seleciono o index desejado junto com a coluna desejada
                                                        #usando o CMD LOC, eu estou utilizando somente os rotulos
# Out:
#                     Motor      Valor
# Nome
# Passat       Motor Diesel  106161.94
# Crossfox  Motor Diesel V8   72832.16

# %%
dataset.loc[:, ['Motor', 'Valor']] #selecionar todas as linhas, porem com as colunas especificadas.
#atençao nos colchetes
# Out:
#                                        Motor      Valor
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Utilizando .iloc para seleções
#
# <font color=red>**Observação:**</font> Seleciona com base nos índices, ou seja, se baseia na posição das informações.

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.iloc[1] #seleciona a informaçao do indice 1 (linha1 = passat)
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.iloc[[1]]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[:4]
# Out:
#                          Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# Passat            Motor Diesel  1991         5712.0    False
# Crossfox       Motor Diesel V8  1990        37123.0    False
# DS5            Motor 2.4 Turbo  2019            NaN     True
#
#                                                       Acessórios      Valor
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat         ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox       ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5            ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.iloc[1:4, [0, 5, 2]] #selecionando linhas e colunas especificas na ordem que eu quero
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %%
dataset.iloc[[1, 22, 4], [0, 5, 2]] #vou selecionar exatamente as linhas que quero juntamente com as colunas que quero, ambas na ordem desejada
# Out:
#                                Motor      Valor  Quilometragem
# Nome
# Passat                  Motor Diesel  106161.94         5712.0
# Lamborghini Obvious  Motor Diesel V6  133529.84        98079.0
# Aston Martin DB4     Motor 2.4 Turbo   92612.10        25757.0

# %%
dataset.iloc[:, [0, 5, 2]] #todas as linhas
# Out:
#                                        Motor      Valor  Quilometragem
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64        44410.0
# Passat                          Motor Diesel  106161.94         5712.0
# Crossfox                     Motor Diesel V8   72832.16        37123.0
# DS5                          Motor 2.4 Turbo  124549.07            NaN
# Aston Martin DB4             Motor 2.4 Turbo   92612.10        25757.0
# ...                                      ...        ...            ...
# Phantom 2013                        Motor V8   51759.58        27505.0
# Cadillac Ciel concept               Motor V8   51667.06        29981.0
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03        52637.0
# Aston Martin DB5                Motor Diesel  122110.90         7685.0
# Macan                        Motor Diesel V6   90381.47        50188.0
#
# [258 rows x 3 columns]

# %% [markdown]
# # 5.3 Queries com DataFrames

# %%
#consultas no dataframe
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
#fazer uma consulta que traga informaçoes de motorizaçao
dataset.Motor
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor == 'Motor Diesel' #CMD == faz comparaçao, vai retornar tudo que tiver MOTOR DIESEL como series booleana
# Out:
# Nome
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
#consigo com essa series, fazer seleçoes no dataframe
select = dataset.Motor == 'Motor Diesel' #definindo a variavel pra ficar mais facil

# %%
select
# Out:
# Nome
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
type(select)
# Out:
# pandas.core.series.Series

# %%
dataset[select] #vai mostrar tudo que for true na variavel select (nesse caso tudo que tiver motor diesel)
# Out:
#                               Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat                 Motor Diesel  1991         5712.0    False
# Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# Sorento                Motor Diesel  2019            NaN     True
# New Fiesta Hatch       Motor Diesel  2017       118895.0    False
# Kangoo Express         Motor Diesel  2007        29132.0    False
# Fit                    Motor Diesel  2013        44329.0    False
# Cielo Hatch            Motor Diesel  2019            NaN     True
# Symbol                 Motor Diesel  2016       117714.0    False
# A4 Sedan               Motor Diesel  2002        30511.0    False
# A4 Avant               Motor Diesel  2014        17357.0    False
# Silver Shadow          Motor Diesel  2015        99052.0    False
# Camry                  Motor Diesel  2019            NaN     True
# Clio                   Motor Diesel  1990        66437.0    False
# ...

# %%
#vamos supor que eu queira motor diesel e que seja 0km
dataset[(select) & (dataset.Zero_km == True)] #condiçao & para combinar, aqui vai procurar pelos dados setados
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
(select) & (dataset.Zero_km == True) #series booleana com todos dados caso queira ver
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Length: 258, dtype: bool

# %% [markdown]
# ### Utilizando o método query

# %%
#outra forma de pesquisa com outro metodo
dataset.query('Motor == "Motor Diesel" and Zero_km == True') #na coluna motor, pesquisa por motores diesel e (CMD AND para query) que na coluna zero-km sejam do tipo True
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %% [markdown]
# # 5.4 Iterando com DataFrames

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
for item in dataset: #porem nao é muito util assim
  print(item) #vai mostrar os rotulos das colunas
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
dataset.iterrows() #cria tuplas com indice e dados
# Out:
# <generator object DataFrame.iterrows at 0x7f6d74003050>

# %%
list(dataset.iterrows())
# Out:
# [('Jetta Variant',
#   Motor                                              Motor 4.0 Turbo
#   Ano                                                           2003
#   Quilometragem                                              44410.0
#   Zero_km                                                      False
#   Acessórios       ['Rodas de liga', 'Travas elétricas', 'Piloto ...
#   Valor                                                     88078.64
#   Name: Jetta Variant, dtype: object),
#  ('Passat', Motor                                                 Motor Diesel
#   Ano                                                           1991
#   Quilometragem                                               5712.0
#   Zero_km                                                      False
#   Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
#   Valor                                                    106161.94
#   Name: Passat, dtype: object),
#  ('Crossfox',
# ...

# %%
for index, row in dataset.iterrows(): #como o CMD ITERROWS cria uma tupla com 2 informaçoes, pore isso vou usar 2 variaveis para FOR
  if(2019 - row['Ano'] != 0): #vai subtrair 2019 por tudo que estiver na coluna ANO, porem somente o que for diferente de 0 para nao dar erro (NaN)
    dataset.loc[index, 'km_media'] = row['Quilometragem'] / (2019 - row['Ano']) #lembrando que o LOC acessa pelo indice e o iloc pelo numero
    # CMD dataset.loc[index, 'km_media'] cria uma nova coluna e que neste caso vai ser o calculo da media de km rodade
  else: #vou ter que fazer tratamento para caso o valor de 0 (para nao dar erro)
    dataset.loc[index, 'km_media'] = 0 #evita que de o erro

dataset #alem de criar a coluna km media adiciona o 0 para veiculos 0km
#porem nao é sustentavel fazer assim, pois dependendo do tamanho do datafram, pode ficar muito pesado
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %% [markdown]
# # 5.5 Tratamento de dados

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios  \
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...
# Crossfox          ['Piloto automático', 'Controle de estabilidad...
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...
#
#                       Valor     km_media
# Nome
# Jetta Variant      88078.64  2775.625000
# Passat            106161.94   204.000000
# ...

# %%
dataset.info() #perceba que na coluna quilometragem nem todas as linhsa tem algo preenchido
#nao posso ignorar, sera necessario tratar antes de continura
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_media       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
dataset.Quilometragem.isna() #faz uma series booleana para todas as linha que estiverem vazias (tudo que for True é pq estava com linha vazia)
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()] #vai retornar as 61 linhas que estavam faltando no comando info
# Out:
#                                 Motor   Ano  Quilometragem  Zero_km  \
# Nome
# DS5                   Motor 2.4 Turbo  2019            NaN     True
# A5                    Motor 4.0 Turbo  2019            NaN     True
# J5                           Motor V6  2019            NaN     True
# A3                       Motor 1.0 8v  2019            NaN     True
# Série 1 M                    Motor V8  2019            NaN     True
# ...                               ...   ...            ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# Benni Mini                   Motor V8  2019            NaN     True
# Uno                   Motor Diesel V6  2019            NaN     True
# Santa Fe                Motor 3.0 32v  2019            NaN     True
# XC60                  Motor 4.0 Turbo  2019            NaN     True
#
#                                                              Acessórios  \
# Nome
# ...

# %%
#para continuar, tenho que trocar os erros por outro dados (nesse caso trocar Nan por 0)
dataset.fillna(0, inplace = True) #preencher tudo que estiver com NaN por 0 E gravar na memoria do dataframe (se deixar sem o INPLACE, vai mudar somente nessa visualizaçao e depois some)

# %%
dataset #alterado NaN por 0
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.query('Zero_km == True') #só para visualizar que tudo foi alterado
# Out:
#                                 Motor   Ano  Quilometragem  Zero_km  \
# Nome
# DS5                   Motor 2.4 Turbo  2019            0.0     True
# A5                    Motor 4.0 Turbo  2019            0.0     True
# J5                           Motor V6  2019            0.0     True
# A3                       Motor 1.0 8v  2019            0.0     True
# Série 1 M                    Motor V8  2019            0.0     True
# ...                               ...   ...            ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019            0.0     True
# Benni Mini                   Motor V8  2019            0.0     True
# Uno                   Motor Diesel V6  2019            0.0     True
# Santa Fe                Motor 3.0 32v  2019            0.0     True
# XC60                  Motor 4.0 Turbo  2019            0.0     True
#
#                                                              Acessórios  \
# Nome
# ...

# %%
dataset.info() #veja que agora esta tudo alterado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  258 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_media       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
dataset = pd.read_csv('db.csv', sep = ';') #relendo o arquivo original

# %%
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.dropna(subset = ['Quilometragem'], inplace = True) #tudo que for NaN na coluna quilometragem, a linha será excluida (para caso os dados possam ser excluidos)
dataset #perceba que antes tinha 258 colunas e agora tem 197
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# 5            Palio Weekend          Motor 1.8 16v  2012        10728.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           197 non-null    object
#  1   Motor          197 non-null    object
#  2   Ano            197 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        197 non-null    bool
#  5   Acessórios     197 non-null    object
#  6   Valor          197 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 11.0+ KB
